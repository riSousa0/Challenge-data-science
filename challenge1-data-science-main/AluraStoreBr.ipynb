# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja['Data da Compra'] = pd.to_datetime(loja['Data da Compra'], dayfirst=True, errors='coerce')
loja['ano'] = loja["Data da Compra"].dt.to_period('y')

loja2['Data da Compra'] = pd.to_datetime(loja2['Data da Compra'], dayfirst=True, errors='coerce')
loja2['ano'] = loja2["Data da Compra"].dt.to_period('y')

loja3['Data da Compra'] = pd.to_datetime(loja3['Data da Compra'], dayfirst=True, errors='coerce')
loja3['ano'] = loja3["Data da Compra"].dt.to_period('y')

loja4['Data da Compra'] = pd.to_datetime(loja4['Data da Compra'], dayfirst=True, errors='coerce')
loja4['ano'] = loja4["Data da Compra"].dt.to_period('y')
# Out:
# C:\Users\Ricar\AppData\Local\Temp\ipykernel_12740\2093955548.py:2: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   loja['ano'] = loja["Data da Compra"].dt.to_period('y')
# C:\Users\Ricar\AppData\Local\Temp\ipykernel_12740\2093955548.py:5: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   loja2['ano'] = loja2["Data da Compra"].dt.to_period('y')
# C:\Users\Ricar\AppData\Local\Temp\ipykernel_12740\2093955548.py:8: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   loja3['ano'] = loja3["Data da Compra"].dt.to_period('y')
# C:\Users\Ricar\AppData\Local\Temp\ipykernel_12740\2093955548.py:11: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   loja4['ano'] = loja4["Data da Compra"].dt.to_period('y')

# %%
loja["ano"].value_counts()
# Out:
# ano
# 2021    739
# 2020    715
# 2022    713
# 2023    192
# Freq: Y-DEC, Name: count, dtype: int64

# %%
## faturamento anual loja 1
loja2021 = loja["ano"] == "2021"
loja2021 = loja[loja2021]
vaturamento_loja1_total2021 = loja2021.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja1_total2021 = vaturamento_loja1_total2021.sum()

loja2020 = loja["ano"] == "2020"
loja2020 = loja[loja2020]
vaturamento_loja1_total2020 = loja2020.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja1_total2020 = vaturamento_loja1_total2020.sum()

loja2022 = loja["ano"] == "2022"
loja2022 = loja[loja2022]
vaturamento_loja1_total2022 = loja2022.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja1_total2022 = vaturamento_loja1_total2022.sum()

loja2023 = loja["ano"] == "2023"
loja2023 = loja[loja2023]
vaturamento_loja1_total2023 = loja2023.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja1_total2023 = vaturamento_loja1_total2023.sum()

# %%
## faturamento anual loja 2
loja2021_2 = loja2["ano"] == "2021"
loja2021_2 = loja2[loja2021_2]
vaturamento_loja_total2021_2 = loja2021_2.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2021_2 = vaturamento_loja_total2021_2.sum()

loja2020_2 = loja2["ano"] == "2020"
loja2020_2 = loja2[loja2020_2]
vaturamento_loja_total2020_2 = loja2020_2.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2020_2 = vaturamento_loja_total2020_2.sum()

loja2022_2 = loja2["ano"] == "2022"
loja2022_2 = loja2[loja2022_2]
vaturamento_loja_total2022_2 = loja2022_2.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2022_2 = vaturamento_loja_total2022_2.sum()

loja2023_2 = loja2["ano"] == "2023"
loja2023_2 = loja2[loja2023_2]
vaturamento_loja_total2023_2 = loja2023_2.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2023_2 = vaturamento_loja_total2023_2.sum()

# %%
## faturamento anual loja 3 
loja2021_3 = loja3["ano"] == "2021"
loja2021_3 = loja3[loja2021_3]
vaturamento_loja_total2021_3 = loja2021_3.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2021_3 = vaturamento_loja_total2021_3.sum()

loja2020_3 = loja3["ano"] == "2020"
loja2020_3 = loja3[loja2020_3]
vaturamento_loja_total2020_3 = loja2020_3.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2020_3 = vaturamento_loja_total2020_3.sum()

loja2022_3 = loja3["ano"] == "2022"
loja2022_3 = loja3[loja2022_3]
vaturamento_loja_total2022_3 = loja2022_3.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2022_3 = vaturamento_loja_total2022_3.sum()

loja2023_3 = loja3["ano"] == "2023"
loja2023_3 = loja3[loja2023_3]
vaturamento_loja_total2023_3 = loja2023_3.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2023_3 = vaturamento_loja_total2023_3.sum()

# %%
## faturamento anual loja 4
loja2021_4 = loja4["ano"] == "2021"
loja2021_4 = loja4[loja2021_4]
vaturamento_loja_total2021_4  = loja2021_4.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2021_4 = vaturamento_loja_total2021_4 .sum()

loja2020_4 = loja4["ano"] == "2020"
loja2020_4 = loja4[loja2020_4]
vaturamento_loja_total2020_4 = loja2020_4.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2020_4 = vaturamento_loja_total2020_4.sum()

loja2022_4 = loja4["ano"] == "2022"
loja2022_4 = loja4[loja2022_4]
vaturamento_loja_total2022_4 = loja2022_4.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2022_4 = vaturamento_loja_total2022_4.sum()

loja2023_4 = loja4["ano"] == "2023"
loja2023_4 = loja4[loja2023_4]
vaturamento_loja_total2023_4 = loja2023_4.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja_total2023_4 = vaturamento_loja_total2023_4.sum()

# %%
## vaturamento total
vaturamento_loja4 = loja4.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja4_total = vaturamento_loja4.sum()

vaturamento_loja1 = loja.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja1_total = vaturamento_loja1.sum()

vaturamento_loja2 = loja2.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja2_total = vaturamento_loja2.sum()

vaturamento_loja3 = loja3.groupby("Local da compra")["Preço"].sum().sort_values(ascending=False)
vaturamento_loja3_total = vaturamento_loja3.sum()

# %% [markdown]
# ## 1. Análise do faturamento

# %%
Frete2021_loja1 = loja2021["Frete"].sum()
Frete2021_loja2 = loja2021_2["Frete"].sum()
Frete2021_loja3 = loja2021_3["Frete"].sum()
Frete2021_loja4 = loja2021_4["Frete"].sum()

Frete2020_loja1 = loja2020["Frete"].sum()
Frete2020_loja2 = loja2020_2["Frete"].sum()
Frete2020_loja3 = loja2020_3["Frete"].sum()
Frete2020_loja4 = loja2020_4["Frete"].sum()

Frete2022_loja1 = loja2022["Frete"].sum()
Frete2022_loja2 = loja2022_2["Frete"].sum()
Frete2022_loja3 = loja2022_3["Frete"].sum()
Frete2022_loja4 = loja2022_4["Frete"].sum()

Frete2023_loja1 = loja2023["Frete"].sum()
Frete2023_loja2 = loja2023_2["Frete"].sum()
Frete2023_loja3 = loja2023_3["Frete"].sum()
Frete2023_loja4 = loja2023_4["Frete"].sum()

freteTotal = Frete2020_loja1 + Frete2021_loja1 + Frete2022_loja1, Frete2020_loja2 + Frete2021_loja2 + Frete2022_loja2, Frete2020_loja3 + Frete2021_loja3 + Frete2022_loja3, Frete2020_loja4 + Frete2021_loja4 + Frete2022_loja4 
freteTotal_loja1 = Frete2020_loja1 + Frete2021_loja1 + Frete2022_loja1 + Frete2023_loja1
freteTotal_loja2 = Frete2020_loja2 + Frete2021_loja2 + Frete2022_loja2 + Frete2023_loja2
freteTotal_loja3 = Frete2020_loja3 + Frete2021_loja3 + Frete2022_loja3 + Frete2023_loja3
freteTotal_loja4 = Frete2020_loja4 + Frete2021_loja4 + Frete2022_loja4 + Frete2023_loja4

# %%
vaturamento_total = [vaturamento_loja1_total, vaturamento_loja2_total, vaturamento_loja3_total, vaturamento_loja4_total]
vat2020 = [vaturamento_loja1_total2020, vaturamento_loja_total2020_2, vaturamento_loja_total2020_3, vaturamento_loja_total2020_4]
vat2021 = [vaturamento_loja1_total2021, vaturamento_loja_total2021_2, vaturamento_loja_total2021_3, vaturamento_loja_total2021_4]
vat2022 = [vaturamento_loja1_total2022, vaturamento_loja_total2022_2, vaturamento_loja_total2022_3, vaturamento_loja_total2022_4]
vat2023 = [vaturamento_loja1_total2023, vaturamento_loja_total2023_2, vaturamento_loja_total2023_3, vaturamento_loja_total2023_4]
vaturamento_totalFrete = [vaturamento_loja1_total - freteTotal_loja1, vaturamento_loja2_total - freteTotal_loja2, vaturamento_loja3_total - freteTotal_loja3, vaturamento_loja4_total - freteTotal_loja4]
vat2020Frete = [vaturamento_loja1_total2020 - Frete2020_loja1, vaturamento_loja_total2020_2 - Frete2020_loja2, vaturamento_loja_total2020_3 - Frete2020_loja3, vaturamento_loja_total2020_4 - Frete2020_loja4]
vat2021Frete = [vaturamento_loja1_total2021 - Frete2021_loja1, vaturamento_loja_total2021_2 - Frete2021_loja2, vaturamento_loja_total2021_3 - Frete2021_loja3, vaturamento_loja_total2021_4 - Frete2021_loja4]
vat2022Frete = [vaturamento_loja1_total2022 - Frete2022_loja1, vaturamento_loja_total2022_2 - Frete2022_loja2, vaturamento_loja_total2022_3 - Frete2022_loja3, vaturamento_loja_total2022_4 - Frete2022_loja4]
vat2023Frete = [vaturamento_loja1_total2023 - Frete2023_loja1, vaturamento_loja_total2023_2 - Frete2023_loja2, vaturamento_loja_total2023_3 - Frete2023_loja3, vaturamento_loja_total2023_4 - Frete2023_loja4]
vat_nomes = ["LOJA 1", "LOJA 2", "LOJA 3", "LOJA 4"]
explodepie = [0.1, 0.1, 0.1, 0.1]
eixoxcolors = ['lightcoral', 'bisque', 'lightblue', 'lightgreen']

# %%
fig, ax = plt.subplots(1, 4, figsize=(40, 7))

## 2020
hbars = ax[0].bar(vat_nomes, vat2020, color=eixoxcolors)
plt.text(x=-15, y=152000, s="Valor totais em vendas 2020", fontsize=25, color="gray")

ax[0].spines["right"].set_visible(False)
ax[0].spines["left"].set_visible(False)
ax[0].spines["top"].set_visible(False)
ax[0].spines["bottom"].set_visible(False)
ax[0].get_yaxis().set_visible(False)
ax[0].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## 2021
hbars = ax[1].bar(vat_nomes, vat2021, color=eixoxcolors)
plt.text(x=-10, y=152000, s="Valor totais em vendas 2021", fontsize=25, color="gray")


ax[1].spines["right"].set_visible(False)
ax[1].spines["left"].set_visible(False)
ax[1].spines["top"].set_visible(False)
ax[1].spines["bottom"].set_visible(False)
ax[1].get_yaxis().set_visible(False)
ax[1].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## 2022
hbars = ax[2].bar(vat_nomes, vat2022, color=eixoxcolors)
plt.text(x=-5, y=152000, s="Valor totais em vendas 2022", fontsize=25, color="gray")

ax[2].spines["right"].set_visible(False)
ax[2].spines["left"].set_visible(False)
ax[2].spines["top"].set_visible(False)
ax[2].spines["bottom"].set_visible(False)
ax[2].get_yaxis().set_visible(False)
ax[2].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## 2023
hbars = ax[3].bar(vat_nomes, vat2023, color=eixoxcolors)
plt.text(x=0, y=152000, s="Valor totais em vendas 2023",fontsize=25, color="gray")

ax[3].spines["right"].set_visible(False)
ax[3].spines["left"].set_visible(False)
ax[3].spines["top"].set_visible(False)
ax[3].spines["bottom"].set_visible(False)
ax[3].get_yaxis().set_visible(False)
ax[3].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")
# Out:
# [Text(0, 0, 'R$ 137,681.46'),
#  Text(0, 0, 'R$ 115,246.36'),
#  Text(0, 0, 'R$ 83,892.33'),
#  Text(0, 0, 'R$ 76,643.56')]

# %%
fig, ax = plt.subplots(1, 4, figsize=(40, 7))

## 2020
hbars = ax[0].bar(vat_nomes, vat2020Frete, color=eixoxcolors)
plt.text(x=-15.5, y=152000, s="Vendas em 2020 com o frete", fontsize=25, color="gray")

ax[0].spines["right"].set_visible(False)
ax[0].spines["left"].set_visible(False)
ax[0].spines["top"].set_visible(False)
ax[0].spines["bottom"].set_visible(False)
ax[0].get_yaxis().set_visible(False)
ax[0].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## 2021
hbars = ax[1].bar(vat_nomes, vat2021Frete, color=eixoxcolors)
plt.text(x=-10.5, y=152000, s="Vendas em 2021 com o frete", fontsize=25, color="gray")

ax[1].spines["right"].set_visible(False)
ax[1].spines["left"].set_visible(False)
ax[1].spines["top"].set_visible(False)
ax[1].spines["bottom"].set_visible(False)
ax[1].get_yaxis().set_visible(False)
ax[1].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## 2022
hbars = ax[2].bar(vat_nomes, vat2022Frete, color=eixoxcolors)
plt.text(x=-5.5, y=152000, s="Vendas em 2022 com o frete", fontsize=25, color="gray")

ax[2].spines["right"].set_visible(False)
ax[2].spines["left"].set_visible(False)
ax[2].spines["top"].set_visible(False)
ax[2].spines["bottom"].set_visible(False)
ax[2].get_yaxis().set_visible(False)
ax[2].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## 2023
hbars = ax[3].bar(vat_nomes, vat2023Frete, color=eixoxcolors)
plt.text(x=0, y=152000, s="Vendas em 2023 com o frete",fontsize=25, color="gray")

ax[3].spines["right"].set_visible(False)
ax[3].spines["left"].set_visible(False)
ax[3].spines["top"].set_visible(False)
ax[3].spines["bottom"].set_visible(False)
ax[3].get_yaxis().set_visible(False)
ax[3].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

plt.tight_layout()
# Out:
# C:\Users\Ricar\AppData\Local\Temp\ipykernel_12740\636105665.py:47: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 3, figsize=(30, 7))
## total
hbars = ax[0].bar(vat_nomes, vaturamento_total, color=eixoxcolors)
plt.text(x=-8.5, y=1.5, s="Valor totais em vendas", fontsize=25, color="gray")

ax[0].spines["right"].set_visible(False)
ax[0].spines["left"].set_visible(False)
ax[0].spines["top"].set_visible(False)
ax[0].spines["bottom"].set_visible(False)
ax[0].get_yaxis().set_visible(False)
ax[0].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## totalComFrete
hbars = ax[1].bar(vat_nomes, vaturamento_totalFrete, color=eixoxcolors)
plt.text(x=-5, y=1.5, s="Totais em vendas com frete", fontsize=25, color="gray")

ax[1].spines["right"].set_visible(False)
ax[1].spines["left"].set_visible(False)
ax[1].spines["top"].set_visible(False)
ax[1].spines["bottom"].set_visible(False)
ax[1].get_yaxis().set_visible(False)
ax[1].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")

## Pie
eixoxcolors = ['lightcoral', 'bisque', 'lightblue', 'lightgreen']
plt.text(x=-1.5, y=1.5, s="Distribuição de vendas em 3 anos", fontsize=25, color="gray")
ax[2].pie(vaturamento_total, labels=vat_nomes, wedgeprops={"edgecolor": "black"}, shadow=True, autopct="%1.1f%%", explode=explodepie, colors=eixoxcolors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a766de6b50>,
# ...
#  [Text(0.8177414380681176, 0.8782362668816901, 'LOJA 1'),
#   Text(-0.9154296618742523, 0.7758792007527926, 'LOJA 2'),
#   Text(-0.7676494259123249, -0.9223417798714738, 'LOJA 3'),
#   Text(0.8855249116624441, -0.8098429667690031, 'LOJA 4')],
#  [Text(0.47701583887306853, 0.5123044890143191, '26.1%'),
#   Text(-0.5340006360933138, 0.452596200439129, '25.4%'),
#   Text(-0.4477954984488562, -0.5380327049250263, '24.9%'),
#   Text(0.516556198469759, -0.4724083972819184, '23.6%')])

# %% [markdown]
# # 2. Vendas por Categoria

# %%
vendas2020_categorias_loja1 = loja2020.groupby("Categoria do Produto")["Preço"].count()
vendas2020_categorias_loja2 = loja2020_2.groupby("Categoria do Produto")["Preço"].count()
vendas2020_categorias_loja3 = loja2020_3.groupby("Categoria do Produto")["Preço"].count()
vendas2020_categorias_loja4 = loja2020_4.groupby("Categoria do Produto")["Preço"].count()
## 2021
vendas2021_categorias_loja1 = loja2021.groupby("Categoria do Produto")["Preço"].count()
vendas2021_categorias_loja2 = loja2021_2.groupby("Categoria do Produto")["Preço"].count()
vendas2021_categorias_loja3 = loja2021_3.groupby("Categoria do Produto")["Preço"].count()
vendas2021_categorias_loja4 = loja2021_4.groupby("Categoria do Produto")["Preço"].count()
## 2022
vendas2022_categorias_loja1 = loja2022.groupby("Categoria do Produto")["Preço"].count()
vendas2022_categorias_loja2 = loja2022_2.groupby("Categoria do Produto")["Preço"].count()
vendas2022_categorias_loja3 = loja2022_3.groupby("Categoria do Produto")["Preço"].count()
vendas2022_categorias_loja4 = loja2022_4.groupby("Categoria do Produto")["Preço"].count()
## 2023
vendas2023_categorias_loja1 = loja2023.groupby("Categoria do Produto")["Preço"].count()
vendas2023_categorias_loja2 = loja2023_2.groupby("Categoria do Produto")["Preço"].count()
vendas2023_categorias_loja3 = loja2023_3.groupby("Categoria do Produto")["Preço"].count()
vendas2023_categorias_loja4 = loja2023_4.groupby("Categoria do Produto")["Preço"].count()
nomesLoja1 = pd.DataFrame(vendas2020_categorias_loja1).reset_index()
nomesLoja1 = nomesLoja1["Categoria do Produto"]

nomesLoja2 = pd.DataFrame(vendas2020_categorias_loja2).reset_index()
nomesLoja2 = nomesLoja2["Categoria do Produto"]

nomesLoja3 = pd.DataFrame(vendas2020_categorias_loja3).reset_index()
nomesLoja3 = nomesLoja3["Categoria do Produto"]

nomesLoja4 = pd.DataFrame(vendas2020_categorias_loja4).reset_index()
nomesLoja4 = nomesLoja4["Categoria do Produto"]
nomesLista = list(nomesLoja1.sort_index())
nomes = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]

# %%
vendas_categorias_loja1 = loja.groupby("Categoria do Produto")["Preço"].count()
vendas_categorias_loja2 = loja2.groupby("Categoria do Produto")["Preço"].count()
vendas_categorias_loja3 = loja3.groupby("Categoria do Produto")["Preço"].count()
vendas_categorias_loja4 = loja4.groupby("Categoria do Produto")["Preço"].count()

# %%
x = list(range(len(nomesLista)))
x2 = [pos + 0.20 for pos in x]
x3 = [pos + 0.40 for pos in x]
x4 = [pos + 0.60 for pos in x]

xticks = [pos + 0.30 for pos in x]

# %%
fig, ax = plt.subplots(1, 5, figsize=(40, 7))
alturaTitulo = 8.5

## 2020
hbars = ax[0].barh(x, vendas2020_categorias_loja1, height=0.20, color="lightcoral")
hbars2 = ax[0].barh(x2, vendas2020_categorias_loja2, height=0.20, color="bisque")
hbars3 = ax[0].barh(x3, vendas2020_categorias_loja3, height=0.20, color="lightblue")
hbars4 = ax[0].barh(x4, vendas2020_categorias_loja4, height=0.20, color="lightgreen")

ax[0].spines["right"].set_visible(False)
ax[0].spines["left"].set_visible(False)
ax[0].spines["top"].set_visible(False)
ax[0].spines["bottom"].set_visible(False)
ax[0].get_xaxis().set_visible(False)

ax[0].bar_label(hbars, fmt="{:.0f}", color="red", label_type="center")
ax[0].bar_label(hbars2, fmt="{:.0f}", color='orange', label_type="center")
ax[0].bar_label(hbars3, fmt="{:.0f}", color="blue", label_type="center")
ax[0].bar_label(hbars4, fmt="{:.0f}", color="green", label_type="center")

ax[0].set_yticks(xticks)
ax[0].set_yticklabels(nomesLista, color="darkgray")

plt.text(x=-2600, y=alturaTitulo, s="Vendas por categoria em 2020", fontsize=16, color="darkgray")

## 2021
hbars = ax[1].barh(x, vendas2021_categorias_loja1, height=0.20, color="lightcoral")
hbars2 = ax[1].barh(x2, vendas2021_categorias_loja2, height=0.20, color="bisque")
hbars3 = ax[1].barh(x3, vendas2021_categorias_loja3, height=0.20, color="lightblue")
hbars4 = ax[1].barh(x4, vendas2021_categorias_loja4, height=0.20, color="lightgreen")

ax[1].spines["right"].set_visible(False)
ax[1].spines["left"].set_visible(False)
ax[1].spines["top"].set_visible(False)
ax[1].spines["bottom"].set_visible(False)
ax[1].get_xaxis().set_visible(False)
ax[1].get_yaxis().set_visible(False)

ax[1].bar_label(hbars, fmt="{:.0f}", color="red", label_type="center")
ax[1].bar_label(hbars2, fmt="{:.0f}", color='orange', label_type="center")
ax[1].bar_label(hbars3, fmt="{:.0f}", color="blue", label_type="center")
ax[1].bar_label(hbars4, fmt="{:.0f}", color="green", label_type="center")

plt.text(x=-1900, y=alturaTitulo, s="Vendas por categoria em 2021", fontsize=16, color="darkgray")

## 2022
hbars = ax[2].barh(x, vendas2022_categorias_loja1, height=0.20, color="lightcoral")
hbars2 = ax[2].barh(x2, vendas2022_categorias_loja2, height=0.20, color="bisque")
hbars3 = ax[2].barh(x3, vendas2022_categorias_loja3, height=0.20, color="lightblue")
hbars4 = ax[2].barh(x4, vendas2022_categorias_loja4, height=0.20, color="lightgreen")

ax[2].spines["right"].set_visible(False)
ax[2].spines["left"].set_visible(False)
ax[2].spines["top"].set_visible(False)
ax[2].spines["bottom"].set_visible(False)
ax[2].get_xaxis().set_visible(False)
ax[2].get_yaxis().set_visible(False)

ax[2].bar_label(hbars, fmt="{:.0f}", color="red", label_type="center")
ax[2].bar_label(hbars2, fmt="{:.0f}", color='orange', label_type="center")
ax[2].bar_label(hbars3, fmt="{:.0f}", color="blue", label_type="center")
ax[2].bar_label(hbars4, fmt="{:.0f}", color="green", label_type="center")

plt.text(x=-1280, y=alturaTitulo, s="Vendas por categoria em 2022", fontsize=16, color="darkgray")

## 2023 
hbars = ax[3].barh(x, vendas2023_categorias_loja1, height=0.20, color="lightcoral")
hbars2 = ax[3].barh(x2, vendas2023_categorias_loja2, height=0.20, color="bisque")
hbars3 = ax[3].barh(x3, vendas2023_categorias_loja3, height=0.20, color="lightblue")
hbars4 = ax[3].barh(x4, vendas2023_categorias_loja4, height=0.20, color="lightgreen")

ax[3].spines["right"].set_visible(False)
ax[3].spines["left"].set_visible(False)
ax[3].spines["top"].set_visible(False)
ax[3].spines["bottom"].set_visible(False)
ax[3].get_xaxis().set_visible(False)
ax[3].get_yaxis().set_visible(False)

ax[3].bar_label(hbars, fmt="{:.0f}", color="red", label_type="center")
ax[3].bar_label(hbars2, fmt="{:.0f}", color='orange', label_type="center")
ax[3].bar_label(hbars3, fmt="{:.0f}", color="blue", label_type="center")
ax[3].bar_label(hbars4, fmt="{:.0f}", color="green", label_type="center")

plt.text(x=-680, y=alturaTitulo, s="Vendas por categoria em 2023", fontsize=16, color="darkgray")

## total
hbars = ax[4].barh(x, vendas_categorias_loja1, height=0.20, color="lightcoral")
hbars2 = ax[4].barh(x2, vendas_categorias_loja2, height=0.20, color="bisque")
hbars3 = ax[4].barh(x3, vendas_categorias_loja3, height=0.20, color="lightblue")
hbars4 = ax[4].barh(x4, vendas_categorias_loja4, height=0.20, color="lightgreen")

ax[4].spines["right"].set_visible(False)
ax[4].spines["left"].set_visible(False)
ax[4].spines["top"].set_visible(False)
ax[4].spines["bottom"].set_visible(False)
ax[4].get_xaxis().set_visible(False)
ax[4].get_yaxis().set_visible(False)

ax[4].bar_label(hbars, fmt="{:.0f}", color="red", label_type="center")
ax[4].bar_label(hbars2, fmt="{:.0f}", color='orange', label_type="center")
ax[4].bar_label(hbars3, fmt="{:.0f}", color="blue", label_type="center")
ax[4].bar_label(hbars4, fmt="{:.0f}", color="green", label_type="center")

plt.text(x=-140, y=8.5, s="Total de vendas por categoria no periodos", fontsize=16, color="darkgray")
# Out:
# Text(-140, 8.5, 'Total de vendas por categoria no periodos')

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
avaliacao_loja1 = loja["Avaliação da compra"].mean()
avaliacao_loja2 = loja2["Avaliação da compra"].mean()
avaliacao_loja3 = loja3["Avaliação da compra"].mean()
avaliacao_loja4 = loja4["Avaliação da compra"].mean()

eixox= ["Loja 1", "Loja2", "Loja3", "loja4"]
eixoy= [avaliacao_loja1, avaliacao_loja2, avaliacao_loja3, avaliacao_loja4]
eixoxcolors = ['lightcoral', 'bisque', 'lightblue', 'lightgreen']

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

plt.text(x=0.6, y=4.6, s="Avaliações medias das lojas", fontsize=25, color="darkgray")
axavaliaçoes = ax.bar(eixox, eixoy, color=eixoxcolors)
ax.bar_label(axavaliaçoes, fmt='{:.3f}')
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
valores_Venda_loja = loja.groupby("Produto")["Preço"].sum().sort_values(ascending=False)
unidades_Vendidas_loja = loja["Produto"].value_counts()

# %%
valores_Venda_loja2 = loja2.groupby("Produto")["Preço"].sum().sort_values(ascending=False)
unidades_Vendidas_loja2 = loja2["Produto"].value_counts()

# %%
valores_Venda_loja3 = loja3.groupby("Produto")["Preço"].sum().sort_values(ascending=False)
unidades_Vendidas_loja3 = loja3["Produto"].value_counts()

# %%
valores_Venda_loja4 = loja4.groupby("Produto")["Preço"].sum().sort_values(ascending=False)
unidades_Vendidas_loja4 = loja4["Produto"].value_counts()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
Frete2021_loja1 = loja2021["Frete"].mean()
Frete2021_loja2 = loja2021_2["Frete"].mean()
Frete2021_loja3 = loja2021_3["Frete"].mean()
Frete2021_loja4 = loja2021_4["Frete"].mean()

Frete2020_loja1 = loja2020["Frete"].mean()
Frete2020_loja2 = loja2020_2["Frete"].mean()
Frete2020_loja3 = loja2020_3["Frete"].mean()
Frete2020_loja4 = loja2020_4["Frete"].mean()

Frete2022_loja1 = loja2022["Frete"].mean()
Frete2022_loja2 = loja2022_2["Frete"].mean()
Frete2022_loja3 = loja2022_3["Frete"].mean()
Frete2022_loja4 = loja2022_4["Frete"].mean()

Frete2023_loja1 = loja2023["Frete"].mean()
Frete2023_loja2 = loja2023_2["Frete"].mean()
Frete2023_loja3 = loja2023_3["Frete"].mean()
Frete2023_loja4 = loja2023_4["Frete"].mean()

fretePeriodos_loja1 = [Frete2020_loja1, Frete2021_loja1, Frete2022_loja1]
fretePeriodos_loja2 = [Frete2020_loja2, Frete2021_loja2, Frete2022_loja2]
fretePeriodos_loja3 = [Frete2020_loja3, Frete2021_loja3, Frete2022_loja3]
fretePeriodos_loja4 = [Frete2020_loja4, Frete2021_loja4, Frete2022_loja4]
freteLabel = ["2020", "2021", "2022"]

# %%
fig, ax = plt.subplots(1, 2, figsize=(25,5))

ax[0].spines["right"].set_visible(False)
ax[0].spines["left"].set_visible(False)
ax[0].spines["top"].set_visible(False)
ax[0].spines["bottom"].set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

ax[0].text(x=0, y=39, s="Frete medio durante 2020 e 2022", fontsize=25, color="darkgray")
axfrete_loja1 = ax[0].plot(freteLabel, fretePeriodos_loja1, color='lightcoral', marker="o")
axfrete_loja2 = ax[0].plot(freteLabel, fretePeriodos_loja2, color='bisque', marker="o")
axfrete_loja3 = ax[0].plot(freteLabel, fretePeriodos_loja3, color='lightblue', marker="o")
axfrete_loja4 = ax[0].plot(freteLabel, fretePeriodos_loja4, color='lightgreen', marker="o")
ax[0].get_yaxis().set_visible(False)

for y_vals in [fretePeriodos_loja1, fretePeriodos_loja2, fretePeriodos_loja3, fretePeriodos_loja4]:
    for i, txt in enumerate(y_vals):
        ax[0].annotate(f"{txt:.2f}", (freteLabel[i], y_vals[i]), textcoords="offset points", xytext=(0,10), ha='center')

ax[0].legend(nomes, title="Nome das Lojas")

## Total
hbars = ax[1].bar(eixox, freteTotal, color=eixoxcolors)
ax[1].bar_label(hbars, fmt="R$ {:,.2f}", color="gray")
ax[1].text(x=0, y=99000, s="Valor de frete de 2020 e 2022", fontsize=25, color="darkgray")

ax[1].spines["right"].set_visible(False)
ax[1].spines["left"].set_visible(False)
ax[1].spines["top"].set_visible(False)
ax[1].spines["bottom"].set_visible(False)
ax[1].get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# # Relatorio

# %% [markdown]
# Este relatorio tem como objetvo apoiar o Sr João para uma apoiadas em analises de qual loja teve ser vendida

# %% [markdown]
# ### Com base nos dados das lojas analisados, as seguinte imformaçoes puderam ser tiradas:

# %% [markdown]
# ###### *Observação importante, os dados 2023 não estão completos, para a analise de "frete medio" os dados não foi levada em consideração

# %% [markdown]
# ### Uma visão mais aprofundada sobre os faturamentos

# %% [markdown]
# ![faturaentos.png](attachment:faturaentos.png)

# %% [markdown]
# ![faturamentosFrete.png](attachment:faturamentosFrete.png)

# %% [markdown]
# - Loja 1 se destaca pelo seu alto faturamento, que é o maior entre as lojas, seguida pela loja 2, 3 e 4, respectivamente.
# - Apesar das loja 4 vender bem, ela não tem um bom faturamento, comparado por exemplo há loja 2, que apesar de ter um frete maior que as outras lojas, teve um dos melhores faturamentos, o segundo melhor.

# %% [markdown]
# ![distribuição.png](attachment:distribuição.png)

# %% [markdown]
# - Esse gráfico monstra o impacto da loja1 na distrubiução de vendas, 26.1%
# - Loja 4 tem a menor participação em vendas e o menor faturamento

# %% [markdown]
# ## Fretes

# %% [markdown]
# ![fretes.png](attachment:fretes.png)

# %% [markdown]
# - Loja 2 tem o maior frete medio, apesar de que, como visto acima seu faturamento não foi muito afetado
# - Loja 1 e 4 tem os menores fretes medios

# %% [markdown]
# ## Avaliações

# %% [markdown]
# ![mediaAvaliações.png](attachment:mediaAvaliações.png)

# %% [markdown]
# - As Lojas tiveram uma media de avaliações com diferenças pratica irrelevandes, 4.04 a maior e 3.99 a menor

# %% [markdown]
# ## Conclusão

# %% [markdown]
# - Como visto no graficos acima a loja 4, apesar de ter um grande volume de vendas, ela não tem um bom lucro, e por isso se torna uma forte candidata a ser vendida. Com uma venda futura da loja 4, um possivel investimento na Loja 2 e 3 deve ser cogitado
